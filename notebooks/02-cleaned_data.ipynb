# %%
import pandas as pd

# Read raw file
df = pd.read_csv(
    r"C:\Users\yoga\Desktop\Retail\data_raw\SampleSuperstore.csv",
    encoding="cp1252"
)

# Save cleaned version
df.to_csv(
    r"C:\Users\yoga\Desktop\Retail\data_raw\SampleSuperstore_clean.csv",
    index=False,
    encoding="utf-8"
)

print("Clean CSV exported successfully")
print(df.shape)
# Out:
# Clean CSV exported successfully
# (9994, 21)
